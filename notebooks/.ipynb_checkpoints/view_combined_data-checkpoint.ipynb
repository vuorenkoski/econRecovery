# %% [markdown]
# # View WB, IMF and Covid data combined
#
# Data is previoiusly saved locally in CSV format, where columns are 'Country or Area', 'Item', 'Year', 'Value'.

# %%
import pandas as pd

df=pd.read_csv('IMF_statistics.csv')
df=df.append(pd.read_csv('WB_statistics.csv'))
df=df.append(pd.read_csv('Covid_statistics.csv'))
print('Number of datapoints:',df.shape[0])
# Out:
# Number of datapoints: 4730

# %%
print('Indicators in data')
indicators=df.Item.unique()
for x in indicators:
    print(' ',x)
    print('    years:',df[df.Item==x].Year.unique())
# Out:
# Indicators in data
#   Central Government Debt (Percent of GDP)
#     years: [2017 2018 2019]
#   Real GDP growth (Annual percent change)
#     years: [2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
#   International tourism, number of arrivals
#     years: [2018 2019 2020]
#   Unemployment, total (% of total labor force) (modeled ILO estimate)
#     years: [2018 2019 2020]
#   GDP per capita (current US$)
#     years: [2018 2019 2020]
#   people_vaccinated_per_hundred
#     years: [2021]

# %%
df.to_csv('Combined_statistics.csv', index=False)

countries=df['Country or Area'].unique()
print('Number of countries or areas in data:',len(countries))
df[df['Country or Area']=='Finland']
# Out:
# Number of countries or areas in data: 310
#      Country or Area         Value  Year  \
# 48           Finland     51.034599  2017
# 198          Finland     49.337077  2018
# 348          Finland     49.128897  2019
# 501          Finland           3.2  2017
# 667          Finland           1.3  2018
# 833          Finland           1.3  2019
# 999          Finland          -2.9  2020
# 1165         Finland           2.3  2021
# 1331         Finland           2.5  2022
# 1497         Finland           1.5  2023
# 1663         Finland           1.3  2024
# 1829         Finland           1.3  2025
# 1995         Finland           1.3  2026
# 225          Finland     3224000.0  2018
# 226          Finland     3290000.0  2019
# 227          Finland           NaN  2020
# 1023         Finland          7.36  2018
# 1024         Finland           6.7  2019
# 1025         Finland          7.83  2020
# 1821         Finland  50013.294203  2018
# 1822         Finland  48711.564208  2019
# 1823         Finland  49041.342257  2020
# 71           Finland          74.5  2021
#
#                                                    Item Code3
# 48             Central Government Debt (Percent of GDP)   FIN
# 198            Central Government Debt (Percent of GDP)   FIN
# 348            Central Government Debt (Percent of GDP)   FIN
# 501             Real GDP growth (Annual percent change)   FIN
# 667             Real GDP growth (Annual percent change)   FIN
# 833             Real GDP growth (Annual percent change)   FIN
# 999             Real GDP growth (Annual percent change)   FIN
# 1165            Real GDP growth (Annual percent change)   FIN
# 1331            Real GDP growth (Annual percent change)   FIN
# 1497            Real GDP growth (Annual percent change)   FIN
# 1663            Real GDP growth (Annual percent change)   FIN
# 1829            Real GDP growth (Annual percent change)   FIN
# 1995            Real GDP growth (Annual percent change)   FIN
# 225           International tourism, number of arrivals   FIN
# 226           International tourism, number of arrivals   FIN
# 227           International tourism, number of arrivals   FIN
# 1023  Unemployment, total (% of total labor force) (...   FIN
# 1024  Unemployment, total (% of total labor force) (...   FIN
# 1025  Unemployment, total (% of total labor force) (...   FIN
# 1821                       GDP per capita (current US$)   FIN
# 1822                       GDP per capita (current US$)   FIN
# 1823                       GDP per capita (current US$)   FIN
# 71                        people_vaccinated_per_hundred   FIN

# %%
df.shape
# Out:
# (4730, 5)

# %%
ccodes=pd.read_csv('countries.csv')[['Code2','Code3']]
ccodes.head()
# Out:
#   Code2 Code3
# 0    DZ   DZA
# 1    EG   EGY
# 2    LY   LBY
# 3    MA   MAR
# 4    SD   SDN

# %%
df=pd.merge(df, ccodes, on=['Code3'], how='left')
df.head()
# Out:
#        Country or Area      Value  Year  \
# 0          Afghanistan  7.9976602  2017
# 1              Albania  70.118725  2017
# 2              Algeria  27.259228  2017
# 3               Angola  69.264947  2017
# 4  Antigua and Barbuda  92.322144  2017
#
#                                        Item Code3 Code2
# 0  Central Government Debt (Percent of GDP)   AFG    AF
# 1  Central Government Debt (Percent of GDP)   ALB    AL
# 2  Central Government Debt (Percent of GDP)   DZA    DZ
# 3  Central Government Debt (Percent of GDP)   AGO    AO
# 4  Central Government Debt (Percent of GDP)   ATG    AG

# %%
df.to_csv('Combined_statistics.csv', index=False)

# %%
df[df.Code3=='RUS']
# Out:
#          Country or Area         Value  Year  \
# 112   Russian Federation     13.494538  2017
# 262   Russian Federation     12.822912  2018
# 412   Russian Federation     13.111517  2019
# 574   Russian Federation           1.8  2017
# 740   Russian Federation           2.8  2018
# 906   Russian Federation             2  2019
# 1072  Russian Federation          -3.1  2020
# 1238  Russian Federation           3.8  2021
# 1404  Russian Federation           3.8  2022
# 1570  Russian Federation           2.1  2023
# 1736  Russian Federation           1.8  2024
# 1902  Russian Federation           1.8  2025
# 2068  Russian Federation           1.8  2026
# 2716  Russian Federation    24551000.0  2018
# 2717  Russian Federation    24419000.0  2019
# 2718  Russian Federation           NaN  2020
# 3514  Russian Federation          4.85  2018
# 3515  Russian Federation           4.6  2019
# 3516  Russian Federation          5.73  2020
# 4312  Russian Federation  11287.355278  2018
# 4313  Russian Federation   11497.64925  2019
# 4314  Russian Federation  10126.721794  2020
# 4670              Russia         32.95  2021
#
#                                                    Item Code3 Code2
# 112            Central Government Debt (Percent of GDP)   RUS    RU
# 262            Central Government Debt (Percent of GDP)   RUS    RU
# 412            Central Government Debt (Percent of GDP)   RUS    RU
# 574             Real GDP growth (Annual percent change)   RUS    RU
# 740             Real GDP growth (Annual percent change)   RUS    RU
# 906             Real GDP growth (Annual percent change)   RUS    RU
# 1072            Real GDP growth (Annual percent change)   RUS    RU
# 1238            Real GDP growth (Annual percent change)   RUS    RU
# 1404            Real GDP growth (Annual percent change)   RUS    RU
# 1570            Real GDP growth (Annual percent change)   RUS    RU
# 1736            Real GDP growth (Annual percent change)   RUS    RU
# 1902            Real GDP growth (Annual percent change)   RUS    RU
# 2068            Real GDP growth (Annual percent change)   RUS    RU
# 2716          International tourism, number of arrivals   RUS    RU
# 2717          International tourism, number of arrivals   RUS    RU
# 2718          International tourism, number of arrivals   RUS    RU
# 3514  Unemployment, total (% of total labor force) (...   RUS    RU
# 3515  Unemployment, total (% of total labor force) (...   RUS    RU
# 3516  Unemployment, total (% of total labor force) (...   RUS    RU
# 4312                       GDP per capita (current US$)   RUS    RU
# 4313                       GDP per capita (current US$)   RUS    RU
# 4314                       GDP per capita (current US$)   RUS    RU
# 4670                      people_vaccinated_per_hundred   RUS    RU
