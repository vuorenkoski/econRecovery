# %% [markdown]
# # Covid statistics

# %%
import pandas as pd
import numpy as np

url = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
df = pd.read_csv(url)

# %% [markdown]
# Select only one column (total_vaccinations_per_hundred). There is lots of other incators too, for example 'fully_vaccinated' etc.

# %%
df.head()
v=df[['people_vaccinated_per_hundred','location','date','iso_code']].dropna()
v=v.rename(columns={'iso_code':'Code3'})

# %% [markdown]
# There is daily data on each country, lets select only most recent date for each country.

# %%
recent=v.groupby('location').apply(lambda df : df.sort_values('date', ascending=False).iloc[0])
recent
# Out:
#                    people_vaccinated_per_hundred           location  \
# location
# Afghanistan                                 2.08        Afghanistan
# Africa                                      7.76             Africa
# Albania                                    34.10            Albania
# Algeria                                    13.49            Algeria
# Andorra                                    70.21            Andorra
# ...                                          ...                ...
# Wallis and Futuna                          52.11  Wallis and Futuna
# World                                      47.76              World
# Yemen                                       1.01              Yemen
# Zambia                                      1.64             Zambia
# Zimbabwe                                   21.48           Zimbabwe
#
#                          date     Code3
# location
# Afghanistan        2021-09-30       AFG
# Africa             2021-10-18  OWID_AFR
# Albania            2021-10-17       ALB
# Algeria            2021-09-25       DZA
# Andorra            2021-09-26       AND
# ...                       ...       ...
# Wallis and Futuna  2021-10-18       WLF
# World              2021-10-18  OWID_WRL
# Yemen              2021-09-27       YEM
# Zambia             2021-09-07       ZMB
# Zimbabwe           2021-10-18       ZWE
#
# [226 rows x 4 columns]

# %% [markdown]
# Data is saved in CSV format, where columns are 'Country or Area', 'Item', 'Year', 'Value'.

# %%
data_name = recent.columns[0]
print(data_name)
recent=recent.drop(['date'],axis=1).rename(columns={'location':'Country or Area', data_name:'Value'})
recent['Item']=data_name
recent['Year']=2021
recent.to_csv('Covid_statistics.csv', index=False)
# Out:
# people_vaccinated_per_hundred

# %%
recent[recent.Code3=='RUS']
# Out:
#           Value Country or Area Code3                           Item  Year
# location
# Russia    35.22          Russia   RUS  people_vaccinated_per_hundred  2021

# %%
df=df[['people_vaccinated_per_hundred','date', 'iso_code']]
df['date']=pd.to_datetime(df.date,format='%Y-%m-%d')
df['year']=df.date.dt.year
df['month']=df.date.dt.month
df['day']=df.date.dt.day

# %%
groups=df.groupby(['year','month','iso_code']).apply(lambda df : df.sort_values('date', ascending=False).iloc[0])
groups.head()
# Out:
#                      people_vaccinated_per_hundred       date iso_code  year  \
# year month iso_code
# 2020 1     ARE                                 NaN 2020-01-31      ARE  2020
#            ARG                                 NaN 2020-01-31      ARG  2020
#            AUS                                 NaN 2020-01-31      AUS  2020
#            CAN                                 NaN 2020-01-31      CAN  2020
#            CHN                                 NaN 2020-01-31      CHN  2020
#
#                      month  day
# year month iso_code
# 2020 1     ARE           1   31
#            ARG           1   31
#            AUS           1   31
#            CAN           1   31
#            CHN           1   31

# %%
groups=groups.drop(['day','date'], axis=1).rename(columns={'people_vaccinated_per_hundred':'value', 'iso_code':'country_code'})
groups['feature_id']=6
groups['value']=pd.to_numeric(groups['value'],errors='coerce')
groups=groups.round({'value':1})
groups
# Out:
#                      value country_code  year  month  feature_id
# year month iso_code
# 2020 1     ARE         NaN          ARE  2020      1           6
#            ARG         NaN          ARG  2020      1           6
#            AUS         NaN          AUS  2020      1           6
#            CAN         NaN          CAN  2020      1           6
#            CHN         NaN          CHN  2020      1           6
# ...                    ...          ...   ...    ...         ...
# 2021 10    WSM        57.6          WSM  2021     10           6
#            YEM         NaN          YEM  2021     10           6
#            ZAF         NaN          ZAF  2021     10           6
#            ZMB         NaN          ZMB  2021     10           6
#            ZWE        21.5          ZWE  2021     10           6
#
# [4320 rows x 5 columns]

# %%
groups.to_csv('Covid_statistics.csv', index=False)
