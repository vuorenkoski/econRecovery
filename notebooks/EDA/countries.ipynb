# %% [markdown]
# # Classification of countries
#
# Source: https://unstats.un.org/unsd/methodology/m49/overview/

# %%
import pandas as pd

df=pd.read_csv('UNSD_countries.csv')

# %%
df.head(20)
# Out:
#     Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0             1       World          2.0      Africa             15.0
# 1             1       World          2.0      Africa             15.0
# 2             1       World          2.0      Africa             15.0
# 3             1       World          2.0      Africa             15.0
# 4             1       World          2.0      Africa             15.0
# 5             1       World          2.0      Africa             15.0
# 6             1       World          2.0      Africa             15.0
# 7             1       World          2.0      Africa            202.0
# 8             1       World          2.0      Africa            202.0
# 9             1       World          2.0      Africa            202.0
# 10            1       World          2.0      Africa            202.0
# 11            1       World          2.0      Africa            202.0
# ...

# %%
df=df.drop(['Global Code','Global Name','Intermediate Region Code','Intermediate Region Name','Intermediate Region Name','Land Locked Developing Countries (LLDC)', 'Small Island Developing States (SIDS)'], axis=1)

# %%
df.head()
# Out:
#    Region Code Region Name  Sub-region Code  Sub-region Name Country or Area  \
# 0          2.0      Africa             15.0  Northern Africa         Algeria
# 1          2.0      Africa             15.0  Northern Africa           Egypt
# 2          2.0      Africa             15.0  Northern Africa           Libya
# 3          2.0      Africa             15.0  Northern Africa         Morocco
# 4          2.0      Africa             15.0  Northern Africa           Sudan
#
#    M49 Code ISO-alpha2 Code ISO-alpha3 Code Least Developed Countries (LDC)  \
# 0        12              DZ             DZA                             NaN
# 1       818              EG             EGY                             NaN
# 2       434              LY             LBY                             NaN
# 3       504              MA             MAR                             NaN
# 4       729              SD             SDN                               x
#
#   Developed / Developing Countries
# ...

# %%
df=df.rename(columns={'ISO-alpha2 Code':'Code2','ISO-alpha3 Code':'Code3'})

# %%
df.shape
# Out:
# (249, 10)

# %%
df.to_csv('countries.csv', index=False)
