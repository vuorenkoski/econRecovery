# %% [markdown]
# # Exploratory analysis on reliance of tourism
#
# Data source: https://databank.worldbank.org/source/world-development-indicators
#
# Used indicators:
#
# - International tourism, number of arrivals (ST.INT.ARVL): International inbound tourists (overnight visitors) are the number of tourists who travel to a country other than that in which they have their usual residence, but outside their usual environment, for a period not exceeding 12 months and whose main purpose in visiting is other than an activity remunerated from within the country visited. When data on number of tourists are not available, the number of visitors, which includes tourists, same-day visitors, cruise passengers, and crew members, is shown instead. Sources and collection methods for arrivals differ across countries. In some cases data are from border statistics (police, immigration, and the like) and supplemented by border surveys. In other cases data are from tourism accommodation establishments. For some countries number of arrivals is limited to arrivals by air and for others to arrivals staying in hotels. Some countries include arrivals of nationals residing abroad while others do not. Caution should thus be used in comparing arrivals across countries. The data on inbound tourists refer to the number of arrivals, not to the number of people traveling. Thus a person who makes several trips to a country during a given period is counted each time as a new arrival.
# - Population, total (SP.POP.TOTL): Total population is based on the de facto definition of population, which counts all residents regardless of legal status or citizenship. The values shown are midyear estimates.
#
# There is no data from year 2020, but 2019 there is. 2019 is last whole year before covid-pandemic.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from io import BytesIO
from zipfile import ZipFile
import requests
import xml.etree.ElementTree as et

# %%
def get_WB_indicator(indicator, year):
    url_base='https://api.worldbank.org/v2/en/indicator/'
    f = requests.get(url_base+indicator+'?downloadformat=xml').content
    zf = ZipFile(BytesIO(f), 'r' )
    data=zf.read(zf.namelist()[0])
    dataroot = et.fromstring(data)
    df = pd.DataFrame()
    for m in dataroot[0]:
        if m.tag=='record':
            d={}
            for x in m:
                d[x.attrib['name']]=x.text
                if x.attrib['name']=='Country or Area':
                    d['Code']=x.attrib['key']
                
            record = pd.Series(data=d, dtype=str, index=['Country or Area', 'Item', 'Year','Value','Code'])
            if int(d['Year'])==year:
                df=df.append(record, ignore_index=True)
    df=df.rename(columns={'Value':indicator}).drop(['Item'], axis=1)
    return df

df1=get_WB_indicator('ST.INT.ARVL', 2019).set_index('Country or Area')
df2=get_WB_indicator('SP.POP.TOTL', 2019).set_index('Country or Area')

# %%
df=pd.concat([df1,df2], axis=1)
df['ST.INT.ARVL per population']=df['ST.INT.ARVL'].astype(float)/df['SP.POP.TOTL'].astype(float)
df.sort_values('ST.INT.ARVL per population', ascending=False).head(20)
# Out:
#                            Year       ST.INT.ARVL Code  Year SP.POP.TOTL Code  \
# Country or Area
# Andorra                    2019           8235000  AND  2019       77146  AND
# Macao SAR, China           2019          39406000  MAC  2019      640446  MAC
# San Marino                 2019           1904000  SMR  2019       33864  SMR
# Sint Maarten (Dutch part)  2019           1952000  SXM  2019       40733  SXM
# Turks and Caicos Islands   2019           1599000  TCA  2019       38194  TCA
# Cayman Islands             2019           2334000  CYM  2019       64948  CYM
# St. Kitts and Nevis        2019           1107000  KNA  2019       52834  KNA
# Virgin Islands (U.S.)      2019           2074000  VIR  2019      106669  VIR
# Bahamas, The               2019           7250000  BHS  2019      389486  BHS
# Aruba                      2019           1951000  ABW  2019      106310  ABW
# Croatia                    2019          60021000  HRV  2019     4065253  HRV
# Bermuda                    2019            805000  BMU  2019       63913  BMU
# Antigua and Barbuda        2019           1035000  ATG  2019       97115  ATG
# British Virgin Islands     2019  302399.993896484  VGB  2019       30033  VGB
# Guam                       2019           1667000  GUM  2019      167295  GUM
# Monaco                     2019            363000  MCO  2019       38967  MCO
# Northern Mariana Islands   2019            487000  MNP  2019       57213  MNP
# Curacao                    2019           1293000  CUW  2019      157441  CUW
# Hong Kong SAR, China       2019          55913000  HKG  2019     7507400  HKG
# Malta                      2019           3519000  MLT  2019      504062  MLT
#
#                            ST.INT.ARVL per population
# Country or Area
# Andorra                                    106.745651
# Macao SAR, China                            61.528997
# San Marino                                  56.224900
# Sint Maarten (Dutch part)                   47.921832
# Turks and Caicos Islands                    41.865214
# Cayman Islands                              35.936441
# St. Kitts and Nevis                         20.952417
# Virgin Islands (U.S.)                       19.443325
# Bahamas, The                                18.614276
# Aruba                                       18.351989
# Croatia                                     14.764395
# Bermuda                                     12.595247
# Antigua and Barbuda                         10.657468
# British Virgin Islands                      10.068924
# Guam                                         9.964434
# Monaco                                       9.315575
# Northern Mariana Islands                     8.512051
# Curacao                                      8.212600
# Hong Kong SAR, China                         7.447718
# Malta                                        6.981284

# %%
df.describe()
# Out:
#        ST.INT.ARVL per population
# count                  213.000000
# mean                     3.383991
# std                     10.716871
# min                      0.001981
# 25%                      0.139905
# 50%                      0.544401
# 75%                      1.799374
# max                    106.745651

# %%
print('Missing values:',df['ST.INT.ARVL per population'].isna().sum())
# Out:
# Missing values: 53

# %%
df[df.index.str.contains('Africa')]
# Out:
#                                                     Year       ST.INT.ARVL  \
# Country or Area
# Africa Eastern and Southern                         2019  39826701.4025488
# Africa Western and Central                          2019              None
# Central African Republic                            2019              None
# Middle East & North Africa                          2019  127987047.716571
# Middle East & North Africa (excluding high income)  2019  67608256.1787089
# Sub-Saharan Africa (excluding high income)          2019   54779421.168165
# Sub-Saharan Africa                                  2019  55251253.9050801
# Middle East & North Africa (IDA & IBRD countries)   2019  66910597.2929825
# Sub-Saharan Africa (IDA & IBRD countries)           2019  55251253.9050801
# South Africa                                        2019          14797000
#
#                                                    Code  Year SP.POP.TOTL  \
# Country or Area
# Africa Eastern and Southern                         AFE  2019   660046272
# Africa Western and Central                          AFW  2019   446911598
# Central African Republic                            CAF  2019     4745179
# Middle East & North Africa                          MEA  2019   456709496
# Middle East & North Africa (excluding high income)  MNA  2019   389457075
# Sub-Saharan Africa (excluding high income)          SSA  2019  1106860245
# Sub-Saharan Africa                                  SSF  2019  1106957870
# Middle East & North Africa (IDA & IBRD countries)   TMN  2019   384771769
# Sub-Saharan Africa (IDA & IBRD countries)           TSS  2019  1106957870
# South Africa                                        ZAF  2019    58558267
#
#                                                    Code  \
# Country or Area
# Africa Eastern and Southern                         AFE
# Africa Western and Central                          AFW
# Central African Republic                            CAF
# Middle East & North Africa                          MEA
# Middle East & North Africa (excluding high income)  MNA
# Sub-Saharan Africa (excluding high income)          SSA
# Sub-Saharan Africa                                  SSF
# Middle East & North Africa (IDA & IBRD countries)   TMN
# Sub-Saharan Africa (IDA & IBRD countries)           TSS
# South Africa                                        ZAF
#
#                                                     ST.INT.ARVL per population
# Country or Area
# Africa Eastern and Southern                                           0.060339
# Africa Western and Central                                                 NaN
# Central African Republic                                                   NaN
# Middle East & North Africa                                            0.280237
# Middle East & North Africa (excluding high income)                    0.173596
# Sub-Saharan Africa (excluding high income)                            0.049491
# Sub-Saharan Africa                                                    0.049913
# Middle East & North Africa (IDA & IBRD countries)                     0.173897
# Sub-Saharan Africa (IDA & IBRD countries)                             0.049913
# South Africa                                                          0.252688

# %%
df[df.index.str.contains('Europe')]
# Out:
#                                                Year       ST.INT.ARVL Code  \
# Country or Area
# Central Europe and the Baltics                 2019  314638365.070248  CEB
# Europe & Central Asia (excluding high income)  2019   180724280.37354  ECA
# Europe & Central Asia                          2019  1183445651.59356  ECS
# European Union                                 2019  966435420.872104  EUU
# Europe & Central Asia (IDA & IBRD countries)   2019  331270663.506501  TEC
#
#                                                Year SP.POP.TOTL Code  \
# Country or Area
# Central Europe and the Baltics                 2019   102398537  CEB
# Europe & Central Asia (excluding high income)  2019   418760880  ECA
# Europe & Central Asia                          2019   920809471  ECS
# European Union                                 2019   447196538  EUU
# Europe & Central Asia (IDA & IBRD countries)   2019   460791608  TEC
#
#                                                ST.INT.ARVL per population
# Country or Area
# Central Europe and the Baltics                                   3.072684
# Europe & Central Asia (excluding high income)                    0.431569
# Europe & Central Asia                                            1.285223
# European Union                                                   2.161098
# Europe & Central Asia (IDA & IBRD countries)                     0.718916

# %%
df[df.index.str.contains('America')]
# Out:
#                                                     Year       ST.INT.ARVL  \
# Country or Area
# American Samoa                                      2019  52700.0007629395
# Latin America & Caribbean (excluding high income)   2019  165231233.608795
# Latin America & Caribbean                           2019   201852567.05797
# North America                                       2019         199244000
# Latin America & the Caribbean (IDA & IBRD count...  2019   172906908.81459
#
#                                                    Code  Year SP.POP.TOTL  \
# Country or Area
# American Samoa                                      ASM  2019       55312
# Latin America & Caribbean (excluding high income)   LAC  2019   589503742
# Latin America & Caribbean                           LCN  2019   646430786
# North America                                       NAC  2019   365987250
# Latin America & the Caribbean (IDA & IBRD count...  TLA  2019   630644771
#
#                                                    Code  \
# Country or Area
# American Samoa                                      ASM
# Latin America & Caribbean (excluding high income)   LAC
# Latin America & Caribbean                           LCN
# North America                                       NAC
# Latin America & the Caribbean (IDA & IBRD count...  TLA
#
#                                                     ST.INT.ARVL per population
# Country or Area
# American Samoa                                                        0.952777
# Latin America & Caribbean (excluding high income)                     0.280289
# Latin America & Caribbean                                             0.312257
# North America                                                         0.544401
# Latin America & the Caribbean (IDA & IBRD count...                    0.274175

# %%
df[df.index.str.contains('Asia')]
# Out:
#                                                Year       ST.INT.ARVL Code  \
# Country or Area
# East Asia & Pacific (excluding high income)    2019  292914980.541575  EAP
# East Asia & Pacific                            2019  487076537.178296  EAS
# Europe & Central Asia (excluding high income)  2019   180724280.37354  ECA
# Europe & Central Asia                          2019  1183445651.59356  ECS
# South Asia                                     2019   26260132.181425  SAS
# East Asia & Pacific (IDA & IBRD countries)     2019   289303382.62936  TEA
# Europe & Central Asia (IDA & IBRD countries)   2019  331270663.506501  TEC
# South Asia (IDA & IBRD)                        2019   26260132.181425  TSA
#
#                                                Year SP.POP.TOTL Code  \
# Country or Area
# East Asia & Pacific (excluding high income)    2019  2093675075  EAP
# East Asia & Pacific                            2019  2340673749  EAS
# Europe & Central Asia (excluding high income)  2019   418760880  ECA
# Europe & Central Asia                          2019   920809471  ECS
# South Asia                                     2019  1835776769  SAS
# East Asia & Pacific (IDA & IBRD countries)     2019  2067982370  TEA
# Europe & Central Asia (IDA & IBRD countries)   2019   460791608  TEC
# South Asia (IDA & IBRD)                        2019  1835776769  TSA
#
#                                                ST.INT.ARVL per population
# Country or Area
# East Asia & Pacific (excluding high income)                      0.139905
# East Asia & Pacific                                              0.208092
# Europe & Central Asia (excluding high income)                    0.431569
# Europe & Central Asia                                            1.285223
# South Asia                                                       0.014305
# East Asia & Pacific (IDA & IBRD countries)                       0.139896
# Europe & Central Asia (IDA & IBRD countries)                     0.718916
# South Asia (IDA & IBRD)                                          0.014305
