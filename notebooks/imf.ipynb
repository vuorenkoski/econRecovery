# %% [markdown]
# # Data retriaval from IMF data
# Data is downloaded manually in excel format. After downlaoded files are converted from xls to xlsx format.
#
# Data is saved in CSV format, where columns are 'Country or Area', 'Item', 'Year', 'Value'.
#
# https://www.imf.org/external/datamapper/CG_DEBT_GDP@GDD/OEMDC/ADVEC/WEOWORLD
#
# https://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD

# %%
import pandas as pd

def extract_from_xlsx(name):
    df = pd.read_excel(name)
    data_name = df.columns[0]
    df=df.rename(columns={data_name:'Country or Area'})
    df2=pd.DataFrame()
    for col in df.columns:
        if col!='Country or Area' and col>2016:
            a=df[['Country or Area',col]].copy()
            a['Year']=col
            a['Item']=data_name
            a=a.rename(columns={col:'Value'}).dropna(subset = ['Country or Area'])
            df2=df2.append(a)
    return df2

# %%
df=extract_from_xlsx('imf_rawdata/imf_debt.xlsx')
df=df.append(extract_from_xlsx('imf_rawdata/imf_gdp_growth.xlsx'))
df.to_csv('IMF_statistics.csv', index=False)
df.head(20)
# Out:
#         Country or Area      Value  Year  \
# 1           Afghanistan    7.99766  2017
# 2               Albania  70.118725  2017
# 3               Algeria  27.259228  2017
# 4                Angola  69.264947  2017
# 5   Antigua and Barbuda  92.322144  2017
# 6             Argentina  57.027842  2017
# 7               Armenia  53.704434  2017
# 8             Australia   32.26376  2017
# 9               Austria  57.046286  2017
# 10           Azerbaijan  22.508608  2017
# 11         Bahamas, The   52.37688  2017
# 12              Bahrain  88.138294  2017
# 13           Bangladesh  33.376308  2017
# 14             Barbados  159.12634  2017
# 15              Belarus  47.214587  2017
# 16              Belgium  86.807024  2017
# 17               Belize  104.39668  2017
# 18                Benin  39.598463  2017
# 19               Bhutan  111.72426  2017
# 20              Bolivia  32.872792  2017
#
#                                         Item
# 1   Central Government Debt (Percent of GDP)
# 2   Central Government Debt (Percent of GDP)
# 3   Central Government Debt (Percent of GDP)
# 4   Central Government Debt (Percent of GDP)
# 5   Central Government Debt (Percent of GDP)
# 6   Central Government Debt (Percent of GDP)
# 7   Central Government Debt (Percent of GDP)
# 8   Central Government Debt (Percent of GDP)
# 9   Central Government Debt (Percent of GDP)
# 10  Central Government Debt (Percent of GDP)
# 11  Central Government Debt (Percent of GDP)
# 12  Central Government Debt (Percent of GDP)
# 13  Central Government Debt (Percent of GDP)
# 14  Central Government Debt (Percent of GDP)
# 15  Central Government Debt (Percent of GDP)
# 16  Central Government Debt (Percent of GDP)
# 17  Central Government Debt (Percent of GDP)
# 18  Central Government Debt (Percent of GDP)
# 19  Central Government Debt (Percent of GDP)
# 20  Central Government Debt (Percent of GDP)

# %%
ccodes=pd.read_csv('countries.csv')

# %%
ccodes.head(10)
# Out:
#    Region Code Region Name  Sub-region Code     Sub-region Name  \
# 0          2.0      Africa             15.0     Northern Africa
# 1          2.0      Africa             15.0     Northern Africa
# 2          2.0      Africa             15.0     Northern Africa
# 3          2.0      Africa             15.0     Northern Africa
# 4          2.0      Africa             15.0     Northern Africa
# 5          2.0      Africa             15.0     Northern Africa
# 6          2.0      Africa             15.0     Northern Africa
# 7          2.0      Africa            202.0  Sub-Saharan Africa
# 8          2.0      Africa            202.0  Sub-Saharan Africa
# 9          2.0      Africa            202.0  Sub-Saharan Africa
#
#                   Country or Area  M49 Code Code2 Code3  \
# 0                         Algeria        12    DZ   DZA
# 1                           Egypt       818    EG   EGY
# 2                           Libya       434    LY   LBY
# 3                         Morocco       504    MA   MAR
# 4                           Sudan       729    SD   SDN
# 5                         Tunisia       788    TN   TUN
# 6                  Western Sahara       732    EH   ESH
# 7  British Indian Ocean Territory        86    IO   IOT
# 8                         Burundi       108    BI   BDI
# 9                         Comoros       174    KM   COM
#
#   Least Developed Countries (LDC) Developed / Developing Countries
# 0                             NaN                       Developing
# 1                             NaN                       Developing
# 2                             NaN                       Developing
# 3                             NaN                       Developing
# 4                               x                       Developing
# 5                             NaN                       Developing
# 6                             NaN                       Developing
# 7                             NaN                       Developing
# 8                               x                       Developing
# 9                               x                       Developing

# %%
ccodes=ccodes[['Country or Area','Code3']]

# %%
df=pd.merge(df, ccodes, on=['Country or Area'], how='left')

# %%
print('Countries before dropping nan:',len(df['Country or Area'].unique()))
# Out:
# Countries before dropping nan: 228

# %%
df[df['Country or Area']=='Finland']
# Out:
#      Country or Area      Value  Year  \
# 53           Finland  51.034599  2017
# 228          Finland  49.337077  2018
# 403          Finland  49.128897  2019
# 583          Finland        3.2  2017
# 811          Finland        1.3  2018
# 1039         Finland        1.3  2019
# 1267         Finland       -2.9  2020
# 1495         Finland        2.3  2021
# 1723         Finland        2.5  2022
# 1951         Finland        1.5  2023
# 2179         Finland        1.3  2024
# 2407         Finland        1.3  2025
# 2635         Finland        1.3  2026
#
#                                           Item Code3
# 53    Central Government Debt (Percent of GDP)   FIN
# 228   Central Government Debt (Percent of GDP)   FIN
# 403   Central Government Debt (Percent of GDP)   FIN
# 583    Real GDP growth (Annual percent change)   FIN
# 811    Real GDP growth (Annual percent change)   FIN
# 1039   Real GDP growth (Annual percent change)   FIN
# 1267   Real GDP growth (Annual percent change)   FIN
# 1495   Real GDP growth (Annual percent change)   FIN
# 1723   Real GDP growth (Annual percent change)   FIN
# 1951   Real GDP growth (Annual percent change)   FIN
# 2179   Real GDP growth (Annual percent change)   FIN
# 2407   Real GDP growth (Annual percent change)   FIN
# 2635   Real GDP growth (Annual percent change)   FIN

# %%
df2=df.dropna()

# %%
print('Countries before dropping nan:',len(df2['Country or Area'].unique()))
# Out:
# Countries before dropping nan: 166

# %%
df
# Out:
#                    Country or Area      Value  Year  \
# 0                      Afghanistan    7.99766  2017
# 1                          Albania  70.118725  2017
# 2                          Algeria  27.259228  2017
# 3                           Angola  69.264947  2017
# 4              Antigua and Barbuda  92.322144  2017
# ...                            ...        ...   ...
# 2800  Middle East and Central Asia        3.6  2026
# 2801      Other advanced economies        2.3  2026
# 2802            Sub-Saharan Africa          4  2026
# 2803                         World        3.3  2026
# 2804                    ©IMF, 2021        NaN  2026
#
#                                           Item Code3
# 0     Central Government Debt (Percent of GDP)   AFG
# 1     Central Government Debt (Percent of GDP)   ALB
# 2     Central Government Debt (Percent of GDP)   DZA
# 3     Central Government Debt (Percent of GDP)   AGO
# 4     Central Government Debt (Percent of GDP)   ATG
# ...                                        ...   ...
# 2800   Real GDP growth (Annual percent change)   NaN
# 2801   Real GDP growth (Annual percent change)   NaN
# 2802   Real GDP growth (Annual percent change)   NaN
# 2803   Real GDP growth (Annual percent change)   NaN
# 2804   Real GDP growth (Annual percent change)   NaN
#
# [2805 rows x 5 columns]

# %%
df2.to_csv('IMF_statistics.csv', index=False)
